# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# %matplotlib inline

# %%
import csv
f = open('kpop.csv')
data = csv.reader(f)
next(data)
result = []

for row in data :
    if row[-1] != '' :
        result.append(float(row[-1]))

font_path = "C:/Windows/Fonts/malgun.ttf"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

import matplotlib.pyplot as plt
plt.figure(figsize = (10,5), dpi = 200)
# # plt.xlim([2016, 2021]) 
# ax=plt.gca()
# ax.axes.xaxis.set_ticks([])
plt.xlabel('year',fontsize=16)
plt.ylabel('count',fontsize=16)
plt.title('시간 흐름에 따른 관심도 변화(2015-2021)',fontsize='20')
plt.plot(result,'blue')
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = '''Korea Korea Korea Korea Korea korea
choreography aespa 
BTS BTS BTS BTS BTS BTS BTS BTS BTS BTS BTS BTS BTS BTS BTS
BLACKPINK BLACKPINK BLACKPINK BLACKPINK
MONSTAX MONSTAX MONSTAX MONSTAX 
EXO EXO EXO EXO 
TWICE TWICE TWICE TWICE 
NCT NCT NCT NCT
TXT TXT ITZY ITZY ITZY ITZY 
seventeen seventeen seventeen seventeen
JENNIE JENNIE JENNIE JENNIE
ROSÉ ROSÉ ROSÉ ROSÉ ROSÉ 
Jessi Jessi Jessi Jessi 
CL CL CL CL
treasure ATEEZ
StrayKids StrayKids StrayKids StrayKids
'''

wc = WordCloud(width=1000, height=600, background_color="white", random_state=0, font_path=r'c:\Windows\Fonts\malgun.ttf')
plt.imshow(wc.generate(text))
plt.axis("off")
plt.show()
